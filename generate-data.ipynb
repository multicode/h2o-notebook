# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
x = np.linspace(0,10,50)

# %%
y = np.sin(x)

# %%
df = pd.DataFrame({'x': x, 'y': y})

# %%
df.plot(x='x', y='y');

# %%
df.to_csv('data.csv')
